# %%
# !nvidia-smi
# Out:
# Wed Mar 26 21:26:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fyB7Pm9ab8YEOFhWO7B5")
project = rf.workspace("jayz-workspace").project("helmet-detector-9rzmg")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !unzip /content/Helmet-Detector-4/roboflow.zip -d /content/Helmet-Detector-4/
# Out:
# Archive:  /content/Helmet-Detector-4/roboflow.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/Helmet-Detector-4/roboflow.zip or
#         /content/Helmet-Detector-4/roboflow.zip.zip, and cannot find /content/Helmet-Detector-4/roboflow.zip.ZIP, period.

# %%
import os
print(os.path.exists('/content/Helmet-Detector-4/roboflow.zip'))
# Out:
# True

# %%
# !file /content/Helmet-Detector-4/roboflow.zip
# Out:
# /content/Helmet-Detector-4/roboflow.zip: Zip archive data, at least v2.0 to extract, compression method=deflate

# %%
# !jar xvf /content/Helmet-Detector-4/roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0594_jpg.rf.1f8645427da10e44c1885cd9e94b2c80.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0594_jpg.rf.303a25f40526e0b171df2deb024cf7f9.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0594_jpg.rf.40bae818b8b7e7785f72b0d1907f5086.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0595_jpg.rf.09ad33973c2cd244bd2710d3c1f7b9fc.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0595_jpg.rf.0a4cf6be88c06e516172a76804c9f162.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0595_jpg.rf.2de43ee48ea42a50d6db6a4af4034963.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0597_jpg.rf.0675a269663aab9fe7106b3d0044a970.txt
#  inflated: train/labels/Change-Out-Your-Hardhat_-Safety-Shorts_mp4-0597_jpg.rf.c3b598481d60d34cae59c614a5324e75.txt
# ...

# %%
dataset.location
# Out:
# '/content/Helmet-Detector-4'

# %%
import os
print(os.path.exists('/content/data.yaml'))
# Out:
# True

# %%
# !yolo task=detect mode=train data=/content/data.yaml model="yolo11n.pt" epochs=5 imgsz=640
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
